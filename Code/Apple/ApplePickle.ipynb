# %%
from google.colab import drive
drive.mount('/content/drive')


import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm


DATADIR = "/content/data"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip "/content/drive/MyDrive/Dataset/Apple/data-20230226T174019Z-001.zip" -d "/content/"

# %%
import imgaug.augmenters as iaa
from matplotlib import pyplot as plt

from google.colab.patches import cv2_imshow

training_data = []

IMG_SIZE = 80

CATEGORIES = ['Apple___Apple_scab','Apple___Black_rot','Apple___Cedar_apple_rust','Apple___healthy']

from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.utils import array_to_img
from tensorflow.keras.utils import load_img

def create_training_data():
    for category in CATEGORIES:  # do
        path = os.path.join(DATADIR,category)
        class_num = CATEGORIES.index(category)
        for img in tqdm(os.listdir(path)):  # iterate over each image
            try:
                #augmentation of data
                image_new = cv2.imread(os.path.join(path,img))
                #cv2_imshow(image_new)
                if class_num == 2:
                  augmentation = iaa.Sequential([iaa.Fliplr(1)])
                  augmented_image = augmentation(image = image_new)
                  #img_array_new = cv2.imread(augmented_image)
                  new_array_new = cv2.resize(augmented_image, (IMG_SIZE, IMG_SIZE))
                  training_data.append([new_array_new,class_num])

                img_array = cv2.imread(os.path.join(path,img))  # convert to array
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  # resize to normalize data size
                training_data.append([new_array, class_num])  # add this to our training_data

            except Exception as e:  # in the interest in keeping the output clean...
                print(e)


create_training_data()

print(len(training_data))
# Out:
# 100%|██████████| 630/630 [00:01<00:00, 447.02it/s]
# 100%|██████████| 621/621 [00:01<00:00, 428.87it/s]
# 100%|██████████| 275/275 [00:00<00:00, 404.74it/s]
# 100%|██████████| 1645/1645 [00:04<00:00, 376.33it/s]
# 3446

# %%
import random

random.shuffle(training_data)

X = []
y = []

for features,label in training_data:
    X.append(features)
    y.append(label)


X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 3)
y = np.array(y)

# %%
X.shape
# Out:
# (3446, 80, 80, 3)

# %%
y.shape
# Out:
# (3446,)

# %%
import pickle

pickle_out = open("/content/drive/MyDrive/Dataset/Apple/X.pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("/content/drive/MyDrive/Dataset/Apple/y.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()
